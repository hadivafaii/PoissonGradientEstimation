# %%
a = (1, 2, 3)
reversed_a = a[::-1]

# %%
reversed_a
# Out:
# (3, 2, 1)

# %%
import torch

# %%
torch.lgamma(torch.tensor([0.0, 1.0, 2.0, 3.0]))
# Out:
# tensor([   inf, 0.0000, 0.0000, 0.6931])
