# %%
import ast
import sys
import os
from itertools import product

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch
import pandas as pd
import plotly.express as px
import torch.nn.functional as F
from torch import nn
from scipy.io import loadmat
from torch.utils.data import DataLoader
from tqdm import tqdm
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import balanced_accuracy_score

sys.path.insert(1, "/".join(os.path.abspath("").split("/")[0:-1]))
import models

from importlib import reload

reload(models)
# Out:
# <module 'models' from '/coc/flash12/cli726/_PoissonGradEstim/main/poglm/models.py'>

# %%
trial_list = np.arange(10)[:1]
method_list = ["score", "GS", "exp"]
upperbound_list = [5, 8, 10, 15]
temp_list = [0.1, 0.2, 0.5, 1.0]
n_monte_carlo_list = [1, 2, 5, 10]
seed_list = np.arange(0, 3)

# %%
tag = "baseline"

df_result = []
idx = 0
for (
    trial,
    method,
    upperbound,
    temp,
    n_monte_carlo,
    seed,
) in product(
    trial_list,
    method_list,
    upperbound_list,
    temp_list,
    n_monte_carlo_list,
    seed_list,
):
    results_folder = (
        f"results_{tag}/{trial}_{method}_{upperbound}_{temp}_{n_monte_carlo}_{seed}"
    )
    try:
        df_temp = pd.read_csv(f"{results_folder}/metrics_last.csv")
        df_temp["trial"] = trial
        df_temp["method"] = method
        df_temp["upperbound"] = upperbound
        df_temp["temp"] = temp
        df_temp["n_monte_carlo"] = n_monte_carlo
        df_temp["seed"] = seed
        df_result.append(df_temp)
    except:
        print(
            idx,
            f"{results_folder} not found",
        )
    idx += 1

df_result = pd.concat(df_result, ignore_index=True)

# %%
fig, axs = plt.subplots(3, 3, figsize=(12, 12), layout="constrained")

for ax, metric in zip(
    axs.flat,
    ["elbo", "mll", "cll", "hll", "weights_error", "bias_error", "running_time"],
):
    sns.boxplot(
        # data=df_result[(df_result["temp"] == 0.1) & (df_result["n_monte_carlo"] == 10)],
        data=df_result,
        x="method",
        hue="upperbound",
        y=metric,
        ax=ax,
        showfliers=False,
        showmeans=True,
        meanprops={
            "markerfacecolor": "white",
            "markeredgecolor": "black",
        },
    )
    ax.set_title(metric)

# %%
fig, axs = plt.subplots(3, 3, figsize=(12, 12), layout="constrained")

for ax, metric in zip(
    axs.flat,
    ["elbo", "mll", "cll", "hll", "weights_error", "bias_error", "running_time"],
):
    sns.boxplot(
        # data=df_result[(df_result["temp"] == 0.1) & (df_result["n_monte_carlo"] == 10)],
        data=df_result,
        x="method",
        hue="temp",
        y=metric,
        ax=ax,
        showfliers=False,
        showmeans=True,
        meanprops={
            "markerfacecolor": "white",
            "markeredgecolor": "black",
        },
    )
    ax.set_title(metric)

# %%
fig, axs = plt.subplots(3, 3, figsize=(12, 12), layout="constrained")

for ax, metric in zip(
    axs.flat,
    ["elbo", "mll", "cll", "hll", "weights_error", "bias_error", "running_time"],
):
    sns.boxplot(
        # data=df_result[(df_result["temp"] == 0.1) & (df_result["n_monte_carlo"] == 10)],
        data=df_result,
        x="method",
        hue="n_monte_carlo",
        y=metric,
        ax=ax,
        showfliers=False,
        showmeans=True,
        meanprops={
            "markerfacecolor": "white",
            "markeredgecolor": "black",
        },
    )
    ax.set_title(metric)

# %% [markdown]
# ## Pick temp == 0.1

# %%
fig, axs = plt.subplots(3, 3, figsize=(12, 12), layout="constrained")

for ax, metric in zip(
    axs.flat,
    ["elbo", "mll", "cll", "hll", "weights_error", "bias_error", "running_time"],
):
    sns.boxplot(
        data=df_result[(df_result["temp"] == 0.1)],
        x="method",
        hue="upperbound",
        y=metric,
        ax=ax,
        showfliers=False,
        showmeans=True,
        meanprops={
            "markerfacecolor": "white",
            "markeredgecolor": "black",
        },
    )
    ax.set_title(metric)

# %%
fig, axs = plt.subplots(3, 3, figsize=(12, 12), layout="constrained")

for ax, metric in zip(
    axs.flat,
    ["elbo", "mll", "cll", "hll", "weights_error", "bias_error", "running_time"],
):
    sns.boxplot(
        data=df_result[(df_result["temp"] == 0.1)],
        x="method",
        hue="n_monte_carlo",
        y=metric,
        ax=ax,
        showfliers=False,
        showmeans=True,
        meanprops={
            "markerfacecolor": "white",
            "markeredgecolor": "black",
        },
    )
    ax.set_title(metric)
